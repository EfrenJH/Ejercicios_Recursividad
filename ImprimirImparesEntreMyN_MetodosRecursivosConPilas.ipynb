# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrenJH/Ejercicios_Recursividad/blob/main/ImprimirImparesEntreMyN_MetodosRecursivosConPilas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def imprimirImparesEntreMyN(m, n):
    if type(m) != int:
        raise Exception("m debe ser entero.")
    if type(n) != int or n <= m:
        raise Exception("n debe ser entero mayor que m.")

    m = m + 1 if m % 2 == 0 else m
    n = n - 1 if n % 2 == 0 else n
    imprimirImparesEntreMyNAux(m, n)

def imprimirImparesEntreMyNAux(m, n):
    if m > n:
        print()
    else:
        print(m, end=" ")
        imprimirImparesEntreMyNAux(m + 2, n)

imprimirImparesEntreMyN(2,8)
# Out:
# 3 5 7
